# %% [markdown]
# # Logistic Regression (Titanic_pydatatset)
#
#
#
# https://pydataset.readthedocs.io/en/latest/index.html
#
#
# Dataset is for educational purposes, mainly. It tries to help those approaching Data Science in Python for the first time, who must deal with common (and time consuming) data preparation tasks.

# %%
# !pip install pydataset
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002650B8550F0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pydataset/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002650B8553C0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pydataset/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002650B8555D0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pydataset/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002650B8556C0>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pydataset/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002650B855840>, 'Connection to pypi.org timed out. (connect timeout=15)')': /simple/pydataset/
# ERROR: Could not find a version that satisfies the requirement pydataset (from versions: none)
# ERROR: No matching distribution found for pydataset

# %%
# Import Statements
#from pydataset import data
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
#Get the data
titanic = pd.read_csv('titanic.csv') #data('titanic')
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 649          650         1       3    Stanley, Miss. Amy Zillah Elsie  female
# 170          171         0       1          Van der hoef, Mr. Wyckoff    male
# 547          548         1       2         Padro y Manent, Mr. Julian    male
# 304          305         0       3  Williams, Mr. Howard Hugh "Harry"    male
# 660          661         1       1      Frauenthal, Dr. Henry William    male
#
#       Age  SibSp  Parch         Ticket      Fare Cabin Embarked
# 649  23.0      0      0       CA. 2314    7.5500   NaN        S
# 170  61.0      0      0         111240   33.5000   B19        S
# 547   NaN      0      0  SC/PARIS 2146   13.8625   NaN        C
# 304   NaN      0      0       A/5 2466    8.0500   NaN        S
# 660  50.0      2      0       PC 17611  133.6500   NaN        S

# %%
#Feature Engineering (One hot encoding)
titanic = pd.get_dummies(titanic, drop_first=True) #there is no class one
titanic.sample(15)
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare  \
# 3              4         1       1  35.0      1      0   53.1000
# 306          307         1       1   NaN      0      0  110.8833
# 46            47         0       3   NaN      1      0   15.5000
# 104          105         0       3  37.0      2      0    7.9250
# 732          733         0       2   NaN      0      0    0.0000
# 564          565         0       3   NaN      0      0    8.0500
# 749          750         0       3  31.0      0      0    7.7500
# 386          387         0       3   1.0      5      2   46.9000
# 689          690         1       1  15.0      0      1  211.3375
# 484          485         1       1  25.0      1      0   91.0792
# 532          533         0       3  17.0      1      1    7.2292
# 509          510         1       3  26.0      0      0   56.4958
# 635          636         1       2  28.0      0      0   13.0000
# 764          765         0       3  16.0      0      0    7.7750
# 577          578         1       1  39.0      1      0   55.9000
#
#      Name_Abbott, Mr. Rossmore Edward  Name_Abbott, Mrs. Stanton (Rosa Hunt)  \
# 3                               False                                  False
# 306                             False                                  False
# 46                              False                                  False
# 104                             False                                  False
# 732                             False                                  False
# 564                             False                                  False
# 749                             False                                  False
# 386                             False                                  False
# 689                             False                                  False
# 484                             False                                  False
# 532                             False                                  False
# 509                             False                                  False
# 635                             False                                  False
# 764                             False                                  False
# 577                             False                                  False
#
#      Name_Abelson, Mr. Samuel  ...  Cabin_F G63  Cabin_F G73  Cabin_F2  \
# 3                       False  ...        False        False     False
# 306                     False  ...        False        False     False
# 46                      False  ...        False        False     False
# 104                     False  ...        False        False     False
# 732                     False  ...        False        False     False
# 564                     False  ...        False        False     False
# 749                     False  ...        False        False     False
# 386                     False  ...        False        False     False
# 689                     False  ...        False        False     False
# 484                     False  ...        False        False     False
# 532                     False  ...        False        False     False
# 509                     False  ...        False        False     False
# 635                     False  ...        False        False     False
# 764                     False  ...        False        False     False
# 577                     False  ...        False        False     False
#
#      Cabin_F33  Cabin_F38  Cabin_F4  Cabin_G6  Cabin_T  Embarked_Q  Embarked_S
# 3        False      False     False     False    False       False        True
# 306      False      False     False     False    False       False       False
# 46       False      False     False     False    False        True       False
# 104      False      False     False     False    False       False        True
# 732      False      False     False     False    False       False        True
# 564      False      False     False     False    False       False        True
# 749      False      False     False     False    False        True       False
# 386      False      False     False     False    False       False        True
# 689      False      False     False     False    False       False        True
# 484      False      False     False     False    False       False       False
# 532      False      False     False     False    False       False       False
# 509      False      False     False     False    False       False        True
# 635      False      False     False     False    False       False        True
# 764      False      False     False     False    False       False        True
# 577      False      False     False     False    False       False        True
#
# [15 rows x 1726 columns]

# %%
#Train test split
X_train, X_test, y_train, y_test = train_test_split(titanic.drop('survived_yes', axis=1), titanic['survived_yes'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 2
#       1 #Train test split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(titanic.drop('survived_yes', axis=1), titanic['survived_yes'])
#
# File c:\Users\Rosita\anaconda3\lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)
#    5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)
#    5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\Rosita\anaconda3\lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\Rosita\anaconda3\lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\Rosita\anaconda3\lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['survived_yes'] not found in axis"

# %%
#Train the model using the training data
solver='lbfgs'
LogReg = LogisticRegression(solver=solver)
LogReg.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
#Predicting if a class-l child-age female survived
LogReg.predict(np.array([[0, 0, 1, 1]]))[0]
# Out:
# 1

# %%
LogReg.score(X_test, y_test)
# Out:
# 0.7629179331306991

# %%
#Understanfing the score
prediction = (LogReg.predict(X_test) > 0.5).astype(int)
np.sum(prediction == y_test) / len(y_test)
# Out:
# 0.7629179331306991

# %%
df_titan = pd.read_csv('titanic.csv', header=None)

# %%
#Predicting if a class-l adult-age male survived
LogReg.predict(df_titan.values)

# %%
#Scoring the model
LogReg.predict_proba(df_titan.values)

# %%
accuracies = []
for max_iter in range(3, 10):
    LogReg = LogisticRegression(
        solver='newton-cg',
        max_iter=max_iter,
        random_state=42,
        tol=1e-100
    )
    
    LogReg.fit(X_train, y_train)
    accuracy = LogReg.score(X_test, y_test)
    accuracies.append(accuracy)

# %%
plt.plot(accuracies)
